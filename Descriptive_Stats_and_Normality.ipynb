# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Set up QQ plot
norm_var = np.random.normal(0, 1, 100)
norm_var.sort()

# %% [markdown]
# ### Rayleigh Distribution

# %%
ray_dstr = np.random.rayleigh(1, 100)
ray_dstr.sort()
ray_df = pd.DataFrame({'Rayleigh': ray_dstr})
ray_dstr_mean, ray_dstr_std = ray_dstr.mean(), ray_dstr.std()
print("Mean: {} \nStandard deviation: {}".format(ray_dstr_mean, ray_dstr_std))
# Out:
# Mean: 1.302167286023832
# Standard deviation: 0.6338547359502231

# %%
ray_df.hist(alpha=0.8, color='teal', bins=20)
plt.axvline(ray_dstr_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(ray_dstr_mean - ray_dstr_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(ray_dstr_mean + ray_dstr_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %%
plt.plot(norm_var, ray_dstr, "o")
plt.title("Rayleigh QQ plot")
plt.show()

# %% [markdown]
# ##### Rayleigh Distribution - Analysis
# Based on the QQ plot, the Rayleigh distribution is close to normal with more vairance at the right tail.

# %% [markdown]
# ### Standard Cauchy Distribution

# %%
stdcauchy_dstr = np.random.standard_cauchy(100)
stdcauchy_dstr.sort()
stdcauchy_df = pd.DataFrame({'Standard Cauchy': stdcauchy_dstr})
stdcauchy_mean, stdcauchy_std, stdcauchy_max, stdcauchy_min = stdcauchy_dstr.mean(), stdcauchy_dstr.std(), stdcauchy_dstr.max(), stdcauchy_dstr.min()
print("Mean: {} \nStandard deviation: {}\nMax: {}\nMin: {}".format(stdcauchy_mean, stdcauchy_std, stdcauchy_max, stdcauchy_min))
# Out:
# Mean: -0.04967734913815733
# Standard deviation: 7.246857730576522
# Max: 61.029191452895475
# Min: -19.734407926312777

# %%
stdcauchy_df.hist(alpha=0.8, color='teal', bins=30)
plt.axvline(stdcauchy_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(stdcauchy_mean - stdcauchy_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(stdcauchy_mean + stdcauchy_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %%
plt.plot(norm_var, stdcauchy_dstr, "o")
plt.title("Standard Cauchy QQ plot")
plt.show()

# %% [markdown]
# ##### Standard Cauchy Distribution - Analysis
# The Standard Cauchy distribution cannot be clearly described using mean and standard deviation. The standard deviation does not show how closely most of the data is clustered around the mean. Extreme outliers seem to distort the standard deviation.

# %% [markdown]
# ### Exponential Distribtuion

# %%
exp_dstr = np.random.exponential(1, 100)
exp_dstr.sort()
exp_df = pd.DataFrame({'Exponential': exp_dstr})
exp_mean, exp_std = exp_dstr.mean(), exp_dstr.std()
print("Mean: {} \nStandard deviation: {}".format(exp_mean, exp_std))
# Out:
# Mean: 1.0328253151083755
# Standard deviation: 0.9272216540640592

# %%
exp_df.hist(alpha=0.8, color='teal', bins=20)
plt.axvline(exp_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(exp_mean - exp_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(exp_mean + exp_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %%
plt.plot(norm_var, exp_dstr, "o")
plt.title("Exponential QQ plot")
plt.show()

# %% [markdown]
# ##### Exponential Distribution - Analysis
# The exponential distribution cannot be clearly described using mean and standard deviation. The shape of the distribution is not symmetrical as higher values happen less frequently.

# %% [markdown]
# ### Poisson Distribtution

# %%
poisson_dstr = np.random.poisson(5, 100)
poisson_df = pd.DataFrame({'Poisson': poisson_dstr})
poisson_mean, poisson_std = poisson_dstr.mean(), poisson_dstr.std()
print("Mean: {} \nStandard deviation: {}".format(poisson_mean, poisson_std))
# Out:
# Mean: 4.89
# Standard deviation: 2.5569317550533097

# %%
poisson_df.hist(alpha=0.8, color='teal', bins=10)
plt.axvline(poisson_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(poisson_mean - poisson_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(poisson_mean + poisson_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ##### Poisson Distribution - Analysis
# The poisson distribution cannot be clearly described using mean and standard deviation. The shape of the distribution is not symmetrical.

# %% [markdown]
# ### Zipf Distribution

# %%
zipf_dstr = np.random.zipf(5, 1000)
zipf_dstr.sort()
zipf_df = pd.DataFrame({'Zipf': zipf_dstr})
zipf_mean, zipf_std = zipf_dstr.mean(), zipf_dstr.std()
print("Mean: {} \nStandard deviation: {}".format(zipf_mean, zipf_std))
# Out:
# Mean: 1.041
# Standard deviation: 0.24762673522865017

# %%
zipf_df.hist(alpha=0.8, color='teal', bins=10)
plt.axvline(zipf_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(zipf_mean - zipf_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(zipf_mean + zipf_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ##### Zipf Distribution - Analysis
# The Zipf distribution cannot be clearly described using mean and standard deviation. The shape of the distribution is not symmetrical.

# %% [markdown]
# ### Laplace Distribution

# %%
laplace_dstr = np.random.laplace(size=100)
laplace_dstr.sort()
laplace_df = pd.DataFrame({'Laplace': laplace_dstr})
laplace_mean, laplace_std = laplace_dstr.mean(), laplace_dstr.std()
print("Mean: {} \nStandard deviation: {}".format(laplace_mean, laplace_std))
# Out:
# Mean: 0.11141970902595442
# Standard deviation: 1.3516923510276848

# %%
laplace_df.hist(alpha=0.8, color='teal', bins=40)
plt.axvline(laplace_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(laplace_mean - laplace_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(laplace_mean + laplace_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %%
plt.plot(norm_var, laplace_dstr, "o")
plt.title("Laplace QQ plot")
plt.show()

# %% [markdown]
# ##### Laplace Distribution - Analysis
# The although the Laplace distribution is not perfectly normal, it is fairly close to being symmetrical and so the mean and standard deviation provide a reasonable illustration of the distribution of the data.

# %% [markdown]
# ### Distributions clearly represented by mean and standard deviation
#
# The distributions that can be clearly represented by the mean and standard deviation are symmetrical and have data that is predictably and consistently spread around the mean.

# %% [markdown]
# ### Normally distributed variables
# Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and standard deviation of 1.
# Add them together to create a third variable.
# Graph the third variable using a histogram.
# Compute the mean and standard deviation and plot them as vertical lines on the histogram.
# Evaluate the descriptive statistics against the data.

# %%
r1 = np.random.normal(loc=5.0, scale=0.5, size=1000)
r2 = np.random.normal(loc=10.0, scale=1.0, size=1000)
r3 = r1 + r2
r3_df = pd.DataFrame({'Combination of 2 normally distributed variables': r3})
r3_mean, r3_std = r3.mean(), r3.std()
print("Mean: {} \nStandard deviation: {}".format(r3_mean, r3_std))
# Out:
# Mean: 14.900143838869864
# Standard deviation: 1.109750069262656

# %%
r3_df.hist(alpha=0.8, color='teal', bins=20)
plt.axvline(r3_mean, color='b', linestyle='solid', linewidth=2)
plt.axvline(r3_mean - r3_std, color='b', linestyle='dashed', linewidth=2)
plt.axvline(r3_mean + r3_std, color='b', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# ##### Combination of two normally distributed variables - Analysis
# The mean and standard deviation provides a somewhat accurate description of the distribution of the combination of two normally distributed random variables. The combined variable has a normally distributed shape.

# %%
r1_df = pd.DataFrame({'r1': r1})
r1_df.hist(alpha=0.8, color='teal', bins=20)
plt.axvline(r1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(r1.mean() - r1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(r1.mean() + r1.std(), color='b', linestyle='dashed', linewidth=2)
plt.show()

# %%
r2_df = pd.DataFrame({'r2': r2})
r2_df.hist(alpha=0.8, color='teal', bins=20)
plt.axvline(r2.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(r2.mean() - r2.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(r2.mean() + r2.std(), color='b', linestyle='dashed', linewidth=2)
plt.show()
